# %%
from ipyaladin import Aladin

from mocpy import MOC

import astropy.units as u
from astropy.visualization.wcsaxes.frame import EllipticalFrame
from astropy.wcs import WCS
from astropy.table import QTable
from astropy.table import Table

import matplotlib.pyplot as plt
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
catalog_path = '/Users/brian.merino/aladin_test_2/des_dr2.csv'
catalog = Table.read(catalog_path,format='ascii')
#print(catalog.keys())
catalog[0:10].show_in_notebook()
# Out:
# <i>Table length=10</i>
# <table id="table140225586499152-890675" class="table-striped table-bordered table-condensed">
# ...

# %%
catalog_path = '/Users/brian.merino/aladin_test_2/delve_dr2_25_2501.csv'
catalog = Table.read(catalog_path,format='ascii')
catalog[0:10].show_in_notebook()
# Out:
# <i>Table length=10</i>
# <table id="table140225586499488-248883" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>ra</th><th>dec</th><th>nest4096</th><th>ring256</th><th>random_id</th></tr></thead>
# <tr><td>0</td><td>316.88174119558676</td><td>-28.795287065660247</td><td>197584985</td><td>583045</td><td>25.0</td></tr>
# <tr><td>1</td><td>316.551473</td><td>-0.0409199999999998</td><td>78289466</td><td>393604</td><td>25.0</td></tr>
# <tr><td>2</td><td>352.7318924616473</td><td>-15.49689316339213</td><td>70074914</td><td>498155</td><td>25.0</td></tr>
# <tr><td>3</td><td>24.796881999999997</td><td>-38.515716</td><td>145774333</td><td>638534</td><td>25.0</td></tr>
# <tr><td>4</td><td>41.79049899999999</td><td>-35.662513000000004</td><td>146970206</td><td>622198</td><td>25.0</td></tr>
# <tr><td>5</td><td>34.80010800000001</td><td>-26.723672000000008</td><td>148928716</td><td>569955</td><td>25.0</td></tr>
# ...

# %%
ra  = catalog['ra']
dec = catalog['dec']

new_table = QTable(
    [ra,dec],
    names=["ra","dec"])

# %%
aladin = Aladin()
aladin
# Out:
# Aladin(init_options=['background_color', 'coo_frame', 'fov', 'full_screen', 'grid_color', 'grid_opacity', 'gri…

# %%
aladin.add_table(new_table)
#aladin.add_table(catalog)
